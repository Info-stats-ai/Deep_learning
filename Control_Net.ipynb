# %%
! pip install diffusers==0.14
# Out:
# Collecting diffusers==0.14
#   Downloading diffusers-0.14.0-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.12/dist-packages (from diffusers==0.14) (8.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from diffusers==0.14) (3.19.1)
# Requirement already satisfied: huggingface-hub>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from diffusers==0.14) (0.35.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from diffusers==0.14) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from diffusers==0.14) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from diffusers==0.14) (2.32.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from diffusers==0.14) (11.3.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.10.0->diffusers==0.14) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.10.0->diffusers==0.14) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.10.0->diffusers==0.14) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.10.0->diffusers==0.14) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.10.0->diffusers==0.14) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.10.0->diffusers==0.14) (1.1.10)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata->diffusers==0.14) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers==0.14) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers==0.14) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers==0.14) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers==0.14) (2025.8.3)
# Downloading diffusers-0.14.0-py3-none-any.whl (737 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 737.4/737.4 kB 19.1 MB/s eta 0:00:00
# Installing collected packages: diffusers
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.35.1
#     Uninstalling diffusers-0.35.1:
#       Successfully uninstalled diffusers-0.35.1
# Successfully installed diffusers-0.14.0

# %%
! pip install -q accelerate transformers xformers
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 MB 9.0 MB/s eta 0:00:00

# %%
! pip install -q opencv-contrib-python
! pip install -q controlnet_aux
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 11.5 MB/s eta 0:00:00

# %%
from diffusers import StableDiffusionControlNetPipeline, ControlNetModel
import torch
import cv2
import numpy as np
from PIL import Image
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-2835477045.py in <cell line: 0>()
# ----> 1 from diffusers import StableDiffusionControlNetPipeline, ControlNetModel
#       2 import torch
#       3 import cv2
#       4 import numpy as np
#       5 from PIL import Image
#
# /usr/local/lib/python3.12/dist-packages/diffusers/__init__.py in <module>
#       1 __version__ = "0.14.0"
#       2
# ----> 3 from .configuration_utils import ConfigMixin
#       4 from .utils import (
#       5     OptionalDependencyNotAvailable,
#
# /usr/local/lib/python3.12/dist-packages/diffusers/configuration_utils.py in <module>
#      32
#      33 from . import __version__
# ---> 34 from .utils import DIFFUSERS_CACHE, HUGGINGFACE_CO_RESOLVE_ENDPOINT, DummyObject, deprecate, logging
#      35
#      36
#
# /usr/local/lib/python3.12/dist-packages/diffusers/utils/__init__.py in <module>
#      35 from .deprecation_utils import deprecate
#      36 from .doc_utils import replace_example_docstring
# ---> 37 from .dynamic_modules_utils import get_class_from_dynamic_module
#      38 from .hub_utils import HF_HUB_OFFLINE, http_user_agent
#      39 from .import_utils import (
#
# /usr/local/lib/python3.12/dist-packages/diffusers/utils/dynamic_modules_utils.py in <module>
#      27 from urllib import request
#      28
# ---> 29 from huggingface_hub import HfFolder, cached_download, hf_hub_download, model_info
#      30
#      31 from .. import __version__
#
# ImportError: cannot import name 'cached_download' from 'huggingface_hub' (/usr/local/lib/python3.12/dist-packages/huggingface_hub/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
! pip install huggingface_hub==0.18.0
# Out:
# Requirement already satisfied: huggingface_hub==0.18.0 in /usr/local/lib/python3.12/dist-packages (0.18.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub==0.18.0) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub==0.18.0) (2025.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub==0.18.0) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub==0.18.0) (4.67.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub==0.18.0) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub==0.18.0) (4.15.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub==0.18.0) (25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub==0.18.0) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub==0.18.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub==0.18.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub==0.18.0) (2025.8.3)

# %%
def grid_img(imgs, rows, cols):
  assert len(imgs) == rows*cols

  w, h = imgs[0].size
  grid = Image.new('RGB', size=(cols*w, rows*h))
  grid_w, grid_h = grid.size

  for i, img in enumerate(imgs):
    grid.paste(img, box=(i%cols*w, i//cols*h))
  return grid

# %% [markdown]
# # Generating images using edges
