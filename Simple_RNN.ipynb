# %%
from keras import Sequential
from keras.layers import Dense, SimpleRNN

# %%
model = Sequential()
model.add(SimpleRNN(3, input_shape=(4,5)))
# 4 time steps and 5 features
model.add(Dense(1, activation='sigmoid'))
model.summary()
# total trainable paratmeters are 31
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 3)              │            27 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │             4 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31 (124.00 B)
#  Trainable params: 31 (124.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
print(model.get_weights())
# Out:
# [array([[-0.5878765 , -0.14488786,  0.05680335],
#        [-0.2137276 ,  0.5012534 , -0.14663285],
#        [ 0.59226495,  0.5738484 ,  0.12171668],
#        [ 0.16120285, -0.39632553, -0.63078463],
#        [-0.43092212, -0.51446104,  0.6613051 ]], dtype=float32), array([[-0.8622564 , -0.14952591, -0.4838966 ],
#        [ 0.46720895, -0.6036733 , -0.64598316],
#        [-0.19552423, -0.7830839 ,  0.5903811 ]], dtype=float32), array([0., 0., 0.], dtype=float32), array([[-0.00372481],
#        [ 0.08127928],
#        [ 1.2046157 ]], dtype=float32), array([0.], dtype=float32)]

# %%
print(model.get_weights()[0])
print(model.get_weights()[0].shape)
# Out:
# [[-0.5878765  -0.14488786  0.05680335]
#  [-0.2137276   0.5012534  -0.14663285]
#  [ 0.59226495  0.5738484   0.12171668]
#  [ 0.16120285 -0.39632553 -0.63078463]
#  [-0.43092212 -0.51446104  0.6613051 ]]
# (5, 3)

# %%
print(model.get_weights()[1])
print(model.get_weights()[1].shape)
# Out:
# [[-0.8622564  -0.14952591 -0.4838966 ]
#  [ 0.46720895 -0.6036733  -0.64598316]
#  [-0.19552423 -0.7830839   0.5903811 ]]
# (3, 3)

# %%
print(model.get_weights()[2])
print(model.get_weights()[2].shape)
# Out:
# [0. 0. 0.]
# (3,)

# %%
print(model.get_weights()[3])
print(model.get_weights()[3].shape)
 #hidden to output
# Out:
# [[-0.00372481]
#  [ 0.08127928]
#  [ 1.2046157 ]]
# (3, 1)

# %%
print(model.get_weights()[4])
print(model.get_weights()[4].shape)
# Out:
# [0.]
# (1,)

# %%
# sentient analysis !!
